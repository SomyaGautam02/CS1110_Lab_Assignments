# %% [markdown]
# # ML Assignment 2

# %% [markdown]
# ## Somya Gautam (2020BTechCSE076)

# %% [markdown]
# ### Importin Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error,mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
main = pd.read_csv("House_Rent_Dataset.csv")
main
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# 1     Phool Bagan, Kankurgachi    Kolkata    Semi-Furnished  Bachelors/Family
# 2      Salt Lake City Sector 2    Kolkata    Semi-Furnished  Bachelors/Family
# 3                  Dumdum Park    Kolkata       Unfurnished  Bachelors/Family
# 4                South Dum Dum    Kolkata       Unfurnished         Bachelors
# ...                        ...        ...               ...               ...
# 4741              Bandam Kommu  Hyderabad    Semi-Furnished  Bachelors/Family
# 4742      Manikonda, Hyderabad  Hyderabad    Semi-Furnished  Bachelors/Family
# 4743      Himayath Nagar, NH 7  Hyderabad    Semi-Furnished  Bachelors/Family
# 4744                Gachibowli  Hyderabad    Semi-Furnished            Family
# 4745           Suchitra Circle  Hyderabad       Unfurnished         Bachelors
#
#       Bathroom Point of Contact
# 0            2    Contact Owner
# 1            1    Contact Owner
# 2            1    Contact Owner
# 3            1    Contact Owner
# 4            1    Contact Owner
# ...        ...              ...
# 4741         2    Contact Owner
# 4742         3    Contact Owner
# 4743         3    Contact Agent
# 4744         2    Contact Agent
# 4745         2    Contact Owner
#
# [4746 rows x 12 columns]

# %%
main_shuffled = main.sample(frac=1,random_state=42) 
main_shuffled=main_shuffled.replace(to_replace="Super Area",value=1)
main_shuffled=main_shuffled.replace(to_replace="Carpet Area",value=2)
main_shuffled=main_shuffled.replace(to_replace="Built Area",value=3)
main_shuffled=main_shuffled.replace(to_replace="Unfurnished",value=3)
main_shuffled=main_shuffled.replace(to_replace="Furnished",value=1)
main_shuffled=main_shuffled.replace(to_replace="Semi-Furnished",value=2)
main_shuffled
# Out:
#        Posted On  BHK   Rent  Size             Floor  Area Type  \
# 1566  2022-06-23    2  16000  1100        2 out of 4          1
# 3159  2022-05-12    2  12000   800        2 out of 3          1
# 538   2022-05-10    2  28000   518       5 out of 12          2
# 2630  2022-06-08    3   8000  1500        1 out of 1          2
# 4418  2022-07-06    3  46000  2235  Ground out of 10          2
# ...          ...  ...    ...   ...               ...        ...
# 4426  2022-06-29    3  25000  1500        1 out of 2          2
# 466   2022-06-13    3  20000  1200        3 out of 3          1
# 3092  2022-07-06    2  20000   800      13 out of 17          2
# 3772  2022-05-17    3  85000  3500   Ground out of 1          2
# 860   2022-06-20    1  25000   450        5 out of 7          2
#
#                       Area Locality       City  Furnishing Status  \
# 1566  Jaya Nagar Block 7, Jayanagar  Bangalore                  3
# 3159               Manikandan Nagar    Chennai                  1
# 538                    Bhandup West     Mumbai                  2
# 2630           Cherlopalli TIRUPATI      Delhi                  3
# 4418                     Gachibowli  Hyderabad                  3
# ...                             ...        ...                ...
# 4426    Ayodhya Nagar, Quthbullapur  Hyderabad                  2
# 466                       Bansdroni    Kolkata                  3
# 3092                     Vadapalani    Chennai                  2
# 3772                        T Nagar    Chennai                  2
# 860                   Goregaon West     Mumbai                  2
#
#       Tenant Preferred  Bathroom Point of Contact
# 1566  Bachelors/Family         2    Contact Owner
# 3159  Bachelors/Family         2    Contact Owner
# 538   Bachelors/Family         2    Contact Owner
# 2630  Bachelors/Family         3    Contact Owner
# 4418            Family         5    Contact Agent
# ...                ...       ...              ...
# 4426            Family         3    Contact Owner
# 466   Bachelors/Family         2    Contact Owner
# 3092            Family         2    Contact Agent
# 3772  Bachelors/Family         3    Contact Agent
# 860          Bachelors         2    Contact Agent
#
# [4746 rows x 12 columns]

# %%
test = main_shuffled.tail(1000)
test
# Out:
#        Posted On  BHK   Rent  Size            Floor  Area Type  \
# 2467  2022-05-06    3  40000  1650       1 out of 3          2
# 1645  2022-05-27    2  12000   950       1 out of 2          1
# 3417  2022-05-20    2   5000   800  Ground out of 2          1
# 3476  2022-05-09    3  10000  1000       1 out of 8          2
# 3941  2022-06-10    4  25000  1815       2 out of 5          1
# ...          ...  ...    ...   ...              ...        ...
# 4426  2022-06-29    3  25000  1500       1 out of 2          2
# 466   2022-06-13    3  20000  1200       3 out of 3          1
# 3092  2022-07-06    2  20000   800     13 out of 17          2
# 3772  2022-05-17    3  85000  3500  Ground out of 1          2
# 860   2022-06-20    1  25000   450       5 out of 7          2
#
#                             Area Locality       City  Furnishing Status  \
# 2467                   Dakshini Pitampura      Delhi                  2
# 1645                           Nri Layout  Bangalore                  2
# 3417                           Ayappakkam    Chennai                  3
# 3476  Kelambakkam, Old Mahabalipuram Road    Chennai                  2
# 3941                       Old Bowenpally  Hyderabad                  2
# ...                                   ...        ...                ...
# 4426          Ayodhya Nagar, Quthbullapur  Hyderabad                  2
# 466                             Bansdroni    Kolkata                  3
# 3092                           Vadapalani    Chennai                  2
# 3772                              T Nagar    Chennai                  2
# 860                         Goregaon West     Mumbai                  2
#
#       Tenant Preferred  Bathroom Point of Contact
# 2467  Bachelors/Family         2    Contact Owner
# 1645  Bachelors/Family         2    Contact Owner
# 3417  Bachelors/Family         2    Contact Owner
# 3476  Bachelors/Family         3    Contact Owner
# 3941  Bachelors/Family         3    Contact Owner
# ...                ...       ...              ...
# 4426            Family         3    Contact Owner
# 466   Bachelors/Family         2    Contact Owner
# 3092            Family         2    Contact Agent
# 3772  Bachelors/Family         3    Contact Agent
# 860          Bachelors         2    Contact Agent
#
# [1000 rows x 12 columns]

# %%
training = main_shuffled.drop(test.index)
training
# Out:
#        Posted On  BHK    Rent  Size             Floor  Area Type  \
# 1566  2022-06-23    2   16000  1100        2 out of 4          1
# 3159  2022-05-12    2   12000   800        2 out of 3          1
# 538   2022-05-10    2   28000   518       5 out of 12          2
# 2630  2022-06-08    3    8000  1500        1 out of 1          2
# 4418  2022-07-06    3   46000  2235  Ground out of 10          2
# ...          ...  ...     ...   ...               ...        ...
# 1854  2022-05-11    2    8900  1100        1 out of 2          1
# 4248  2022-06-22    2   12500  1200        2 out of 5          1
# 2872  2022-05-30    2   20000   950        2 out of 3          2
# 3030  2022-05-12    2   14000  1000        1 out of 3          1
# 1205  2022-07-09    3  120000  1130        3 out of 7          2
#
#                                         Area Locality       City  \
# 1566                    Jaya Nagar Block 7, Jayanagar  Bangalore
# 3159                                 Manikandan Nagar    Chennai
# 538                                      Bhandup West     Mumbai
# 2630                             Cherlopalli TIRUPATI      Delhi
# 4418                                       Gachibowli  Hyderabad
# ...                                               ...        ...
# 1854                                    Sarjapur Road  Bangalore
# 4248                                         Kompally  Hyderabad
# 2872  Geeta Colony PRWS Block 3 And 7, Rajgarh Colony      Delhi
# 3030                             Kanathur Reddikuppam    Chennai
# 1205                                      Bandra West     Mumbai
#
#       Furnishing Status  Tenant Preferred  Bathroom Point of Contact
# 1566                  3  Bachelors/Family         2    Contact Owner
# 3159                  1  Bachelors/Family         2    Contact Owner
# 538                   2  Bachelors/Family         2    Contact Owner
# 2630                  3  Bachelors/Family         3    Contact Owner
# 4418                  3            Family         5    Contact Agent
# ...                 ...               ...       ...              ...
# 1854                  2  Bachelors/Family         2    Contact Owner
# 4248                  2  Bachelors/Family         2    Contact Owner
# 2872                  2  Bachelors/Family         2    Contact Owner
# 3030                  3  Bachelors/Family         2    Contact Owner
# 1205                  2  Bachelors/Family         3    Contact Agent
#
# [3746 rows x 12 columns]

# %%
train = training.sample(frac=0.8,random_state=42)
train
# Out:
#        Posted On  BHK   Rent  Size                    Floor  Area Type  \
# 46    2022-05-20    2   4600   400               3 out of 3          2
# 518   2022-06-08    2  45000  1320  Lower Basement out of 2          1
# 3930  2022-07-06    3  75000  2395             14 out of 17          2
# 201   2022-06-24    1  10000   700               1 out of 2          2
# 3520  2022-07-10    3  65000  1444             11 out of 14          1
# ...          ...  ...    ...   ...                      ...        ...
# 2224  2022-06-27    1   6500   450          Ground out of 2          2
# 2293  2022-05-23    1   4000   250          Ground out of 2          1
# 1814  2022-06-22    2   9750   575          Ground out of 2          2
# 1950  2022-05-23    2  12000   650               2 out of 4          1
# 4037  2022-05-06    2  10000  1090               2 out of 4          1
#
#                        Area Locality       City  Furnishing Status  \
# 46                            Behala    Kolkata                  2
# 518                       Ballygunge    Kolkata                  1
# 3930   Vittal Rao Nagar, Hitech City  Hyderabad                  2
# 201                            Garia    Kolkata                  3
# 3520                    Nungambakkam    Chennai                  2
# ...                              ...        ...                ...
# 2224          Garden City University  Bangalore                  2
# 2293                     Vijayanagar  Bangalore                  3
# 1814                        Varanasi  Bangalore                  2
# 1950                    Bommanahalli  Bangalore                  2
# 4037  Hyder Shah Kote, Chevella Road  Hyderabad                  3
#
#       Tenant Preferred  Bathroom Point of Contact
# 46           Bachelors         1    Contact Owner
# 518   Bachelors/Family         2    Contact Owner
# 3930            Family         3    Contact Agent
# 201          Bachelors         1    Contact Owner
# 3520         Bachelors         3    Contact Agent
# ...                ...       ...              ...
# 2224  Bachelors/Family         1    Contact Owner
# 2293  Bachelors/Family         1    Contact Owner
# 1814         Bachelors         2    Contact Owner
# 1950  Bachelors/Family         2    Contact Owner
# 4037  Bachelors/Family         2    Contact Owner
#
# [2997 rows x 12 columns]

# %%
validation = training.drop(train.index)
validation
# Out:
#        Posted On  BHK    Rent  Size             Floor  Area Type  \
# 3159  2022-05-12    2   12000   800        2 out of 3          1
# 4418  2022-07-06    3   46000  2235  Ground out of 10          2
# 4080  2022-06-18    2   12000   500        1 out of 2          1
# 3792  2022-07-06    4  140000  2600        2 out of 2          2
# 2323  2022-07-05    3   60000  1850        3 out of 3          2
# ...          ...  ...     ...   ...               ...        ...
# 4727  2022-06-28    3   30000   214        2 out of 2          1
# 3878  2022-06-28    4   75000  3800       3 out of 10          2
# 2360  2022-05-05    3   24000  1400        2 out of 4          1
# 3502  2022-06-29    3   60000  1800        9 out of 9          1
# 3030  2022-05-12    2   14000  1000        1 out of 3          1
#
#                               Area Locality       City  Furnishing Status  \
# 3159                       Manikandan Nagar    Chennai                  1
# 4418                             Gachibowli  Hyderabad                  3
# 4080            Saidabad Colony, Sayeedabad  Hyderabad                  1
# 3792                           Ranjith Road    Chennai                  2
# 2323                               Halasuru  Bangalore                  1
# ...                                     ...        ...                ...
# 4727                          Jubilee Hills  Hyderabad                  1
# 3878      Financial District, Nanakram Guda  Hyderabad                  2
# 2360  Jalahalli, Jalahalli, Outer Ring Road  Bangalore                  2
# 3502                          in Saligramam    Chennai                  2
# 3030                   Kanathur Reddikuppam    Chennai                  3
#
#       Tenant Preferred  Bathroom Point of Contact
# 3159  Bachelors/Family         2    Contact Owner
# 4418            Family         5    Contact Agent
# 4080  Bachelors/Family         2    Contact Owner
# 3792  Bachelors/Family         4    Contact Agent
# 2323  Bachelors/Family         3    Contact Owner
# ...                ...       ...              ...
# 4727         Bachelors         4    Contact Owner
# 3878  Bachelors/Family         4    Contact Agent
# 2360  Bachelors/Family         3    Contact Owner
# 3502         Bachelors         3    Contact Agent
# 3030  Bachelors/Family         2    Contact Owner
#
# [749 rows x 12 columns]

# %% [markdown]
# # Number of rows in training, validation and test sets, along with the structure, datatypes and value counts of the dataframes

# %%
print(train.dtypes)
print("The number of rows and columns are :",len(train),",",len(train.columns))
# Out:
# Posted On            object
# BHK                   int64
# Rent                  int64
# Size                  int64
# Floor                object
# Area Type             int64
# Area Locality        object
# City                 object
# Furnishing Status     int64
# Tenant Preferred     object
# Bathroom              int64
# Point of Contact     object
# dtype: object
# The number of rows and columns are : 2997 , 12

# %%
print(test.dtypes)
print("The number of rows and columns are :",len(test),",",len(test.columns))
# Out:
# Posted On            object
# BHK                   int64
# Rent                  int64
# Size                  int64
# Floor                object
# Area Type             int64
# Area Locality        object
# City                 object
# Furnishing Status     int64
# Tenant Preferred     object
# Bathroom              int64
# Point of Contact     object
# dtype: object
# The number of rows and columns are : 1000 , 12

# %%
print(validation.dtypes)
print("The number of rows and columns are :",len(validation),",",len(validation.columns))
# Out:
# Posted On            object
# BHK                   int64
# Rent                  int64
# Size                  int64
# Floor                object
# Area Type             int64
# Area Locality        object
# City                 object
# Furnishing Status     int64
# Tenant Preferred     object
# Bathroom              int64
# Point of Contact     object
# dtype: object
# The number of rows and columns are : 749 , 12

# %% [markdown]
# # Data Cleaning:

# %% [markdown]
# * Analyse the data and identify which columns are not relevant for house rent prediction task. Drop
# those columns from the dataframes.*

# %%
train.drop(['Posted On','Area Type','Area Locality','Tenant Preferred','Point of Contact'],axis=1)
# Out:
#       BHK   Rent  Size                    Floor       City  Furnishing Status  \
# 46      2   4600   400               3 out of 3    Kolkata                  2
# 518     2  45000  1320  Lower Basement out of 2    Kolkata                  1
# 3930    3  75000  2395             14 out of 17  Hyderabad                  2
# 201     1  10000   700               1 out of 2    Kolkata                  3
# 3520    3  65000  1444             11 out of 14    Chennai                  2
# ...   ...    ...   ...                      ...        ...                ...
# 2224    1   6500   450          Ground out of 2  Bangalore                  2
# 2293    1   4000   250          Ground out of 2  Bangalore                  3
# 1814    2   9750   575          Ground out of 2  Bangalore                  2
# 1950    2  12000   650               2 out of 4  Bangalore                  2
# 4037    2  10000  1090               2 out of 4  Hyderabad                  3
#
#       Bathroom
# 46           1
# 518          2
# 3930         3
# 201          1
# 3520         3
# ...        ...
# 2224         1
# 2293         1
# 1814         2
# 1950         2
# 4037         2
#
# [2997 rows x 7 columns]

# %% [markdown]
# ####  Check for missing values and logically impute the dataset.

# %%
print("FOR NA VALUE:\n",train.isna().sum(),'\n')
print("FOR NULL VALUE:\n",train.isnull().sum(),'\n')
print("From above we can derive that there is no null value and no Na Values, therefore there is no need of logical imputation")
# Out:
# FOR NA VALUE:
#  Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64
#
# FOR NULL VALUE:
#  Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64
#
# From above we can derive that there is no null value and no Na Values, therefore there is no need of logical imputation

# %% [markdown]
# #####   Identify any categorical valued columns (non-numeric) and convert them to numeric.

# %% [markdown]
# # Exploratory Analysis (On training set):

# %% [markdown]
# #### Plot the house rents against the dependent variable of “size”. See if there is a uniform linear trend between the dependent and independent variables. Make accurate axis and legend. Save the plot in a png file.

# %%
df = train[['Size','Rent']]
df=df.tail(1000)
df.plot(kind='scatter',x='Size',y='Rent')
plt.title('ScatterPlot of Rent vs Size')
plt.legend(["Rent for the x Size Room"])
plt.show()

# %% [markdown]
# #### Find average rent prices in different cities and report which city has the highest average rent.

# %%
df1 = train[['Rent','City']]
m=df1.groupby(["City"],sort=True)['Rent'].mean()
print(m)
print(m.max())
x = train['Rent']
y = train['City']
plt.bar(y,x,color='yellow',width=0.5)
plt.title("Average Rent of Cities")
plt.ylabel("Average Rent")
# Out:
# City
# Bangalore    27585.763060
# Chennai      22145.766372
# Delhi        30994.748031
# Hyderabad    20448.101266
# Kolkata      11909.943953
# Mumbai       85821.845907
# Name: Rent, dtype: float64
# 85821.84590690209
# Text(0, 0.5, 'Average Rent')

# %% [markdown]
# # Regression :

# %%
train_part = train[['BHK','Rent','Bathroom']]
train_part
# Out:
#       BHK   Rent  Bathroom
# 46      2   4600         1
# 518     2  45000         2
# 3930    3  75000         3
# 201     1  10000         1
# 3520    3  65000         3
# ...   ...    ...       ...
# 2224    1   6500         1
# 2293    1   4000         1
# 1814    2   9750         2
# 1950    2  12000         2
# 4037    2  10000         2
#
# [2997 rows x 3 columns]

# %%
model = LinearRegression()

# %% [markdown]
# ####  Train a linear regression model on the training set partition by taking only one dependent variable of “size”. Calculate the error on the validation set

# %%
model.fit(train_part,train['Size'])
# Out:
# LinearRegression()

# %%
test_prediction = model.predict(test[['BHK','Rent','Bathroom']])
df2 = pd.DataFrame(data=test_prediction,columns=["Predicted Size"])
df2
# Out:
#      Predicted Size
# 0       1243.710957
# 1        933.428892
# 2        928.085563
# 3       1495.771253
# 4       1796.129994
# ..              ...
# 995     1507.221243
# 996     1228.444304
# 997      939.535553
# 998     1553.021204
# 999      654.443466
#
# [1000 rows x 1 columns]

# %%
df3=train[['Size']].tail(1000)
df3
# Out:
#       Size
# 4518  3400
# 1472   700
# 265    900
# 1461   774
# 2340  2390
# ...    ...
# 2224   450
# 2293   250
# 1814   575
# 1950   650
# 4037  1090
#
# [1000 rows x 1 columns]

# %%
df3Idx=df3.index.values
df2Idx=df2.index.values

# %%
plt.scatter(y=df3['Size'],x=df3Idx,c="pink",linewidths=1,marker="s",edgecolor="green",s=25)
plt.scatter(y=df2['Predicted Size'],x=df2Idx,c="yellow",linewidths=1,marker="*",edgecolor="red",s=100)
plt.title("Predicted Size v/s True Size")
plt.legend(['Actual','Predicted'])
plt.xlabel("Index of Rows")
plt.ylabel("Size")
plt.show()

# %%
mae = mean_absolute_error(test['Size'],test_prediction)
mae
# Out:
# 272.23283544227365

# %%
mse = mean_squared_error(test['Size'],test_prediction)
mse
# Out:
# 184862.67494014982

# %% [markdown]
# ####  Create a function for calculating the RMSE values for the predictions Vs the actual ground truth rent  values. RMSE = SQRT( Σ ( (F(xi) - yi)2)/N ), Here F(x) are the prediction values, N are the number of rows

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 429.95659657708455

# %% [markdown]
# #### Plot the model predictions of rent values alongside the actual rent values taken for the validation set.Show the legend, axes and color-coded predictions and ground truth for differentiating

# %%
train_part1 = train[['BHK','Size','Bathroom']]
train_part1
# Out:
#       BHK  Size  Bathroom
# 46      2   400         1
# 518     2  1320         2
# 3930    3  2395         3
# 201     1   700         1
# 3520    3  1444         3
# ...   ...   ...       ...
# 2224    1   450         1
# 2293    1   250         1
# 1814    2   575         2
# 1950    2   650         2
# 4037    2  1090         2
#
# [2997 rows x 3 columns]

# %%
model = LinearRegression()

# %%
model.fit(train_part1,train['Rent'])
# Out:
# LinearRegression()

# %%
test_prediction = model.predict(test[['BHK','Size','Bathroom']])
df2 = pd.DataFrame(data=test_prediction,columns=["Predicted Rent"])
df2
# Out:
#      Predicted Rent
# 0      54269.754423
# 1      36956.390874
# 2      32291.704281
# 3      62462.549478
# 4      83352.172748
# ..              ...
# 995    78011.504787
# 996    40275.694646
# 997    32291.704281
# 998   140207.326020
# 999    25862.609448
#
# [1000 rows x 1 columns]

# %%
df3=train[['Rent']].tail(1000)
df3
# Out:
#         Rent
# 4518   35000
# 1472   20000
# 265     8000
# 1461   42000
# 2340  120000
# ...      ...
# 2224    6500
# 2293    4000
# 1814    9750
# 1950   12000
# 4037   10000
#
# [1000 rows x 1 columns]

# %%
plt.scatter(y=df3['Rent'],x=df3Idx,c="pink",linewidths=1,marker="s",edgecolor="green",s=25)
plt.scatter(y=df2['Predicted Rent'],x=df2Idx,c="yellow",linewidths=1,marker="*",edgecolor="red",s=100)
plt.title("Predicted Rent v/s True Rent")
plt.legend(['Actual','Predicted'])
plt.xlabel("Index")
plt.ylabel("Rent")
plt.show()

# %%
mae = mean_absolute_error(test['Rent'],test_prediction)
mse = mean_squared_error(test['Rent'],test_prediction)
rmse = np.sqrt(mse)
rmse
# Out:
# 57766.66921922416

# %% [markdown]
# ### Train a logistic regression model and check the score for different training iterations. Plot the validation results by varying max_iter as 10, 20, 30, ….

# %%
train_part1 = train[['BHK','Size','Bathroom']]
train_part1
# Out:
#       BHK  Size  Bathroom
# 46      2   400         1
# 518     2  1320         2
# 3930    3  2395         3
# 201     1   700         1
# 3520    3  1444         3
# ...   ...   ...       ...
# 2224    1   450         1
# 2293    1   250         1
# 1814    2   575         2
# 1950    2   650         2
# 4037    2  1090         2
#
# [2997 rows x 3 columns]

# %%
modelL = LogisticRegression(max_iter=10,solver='liblinear')
modelL.fit(train_part1,train['Rent'])
modelL
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# LogisticRegression(max_iter=10, solver='liblinear')

# %%
Lprediction=modelL.predict(test[['BHK','Size','Bathroom']])
df2 = pd.DataFrame(data=Lprediction,columns=["Predicted Rent"])
df2
# Out:
#      Predicted Rent
# 0             15000
# 1             15000
# 2             15000
# 3             15000
# 4             15000
# ..              ...
# 995           15000
# 996           15000
# 997           15000
# 998           15000
# 999           15000
#
# [1000 rows x 1 columns]

# %%
mae = mean_absolute_error(test['Rent'],Lprediction)
mse = mean_squared_error(test['Rent'],Lprediction)
rmse = np.sqrt(mse)
rmse
# Out:
# 71637.55118653903

# %% [markdown]
# ### Try to improve accuracy (on validation set) by considering more features and retraining.

# %%
from sklearn.metrics import accuracy_score
score =accuracy_score(test['Rent'],Lprediction)
score
# Out:
# 0.056

# %%
train_part1 = train[['BHK','Size','Area Type','Bathroom']]
train_part1
# Out:
#       BHK  Size  Area Type  Bathroom
# 46      2   400          2         1
# 518     2  1320          1         2
# 3930    3  2395          2         3
# 201     1   700          2         1
# 3520    3  1444          1         3
# ...   ...   ...        ...       ...
# 2224    1   450          2         1
# 2293    1   250          1         1
# 1814    2   575          2         2
# 1950    2   650          1         2
# 4037    2  1090          1         2
#
# [2997 rows x 4 columns]

# %%
modelL = LogisticRegression(max_iter=20,solver='liblinear')
modelL.fit(train_part1,train['Rent'])
modelL
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# LogisticRegression(max_iter=20, solver='liblinear')

# %%
Lprediction=modelL.predict(test[['BHK','Size','Area Type','Bathroom']])
df2 = pd.DataFrame(data=Lprediction,columns=["Predicted Rent"])
df2
# Out:
#      Predicted Rent
# 0             15000
# 1             15000
# 2             15000
# 3             15000
# 4             15000
# ..              ...
# 995           15000
# 996           15000
# 997           15000
# 998          200000
# 999            9000
#
# [1000 rows x 1 columns]

# %%
mae = mean_absolute_error(test['Rent'],Lprediction)
mse = mean_squared_error(test['Rent'],Lprediction)
rmse = np.sqrt(mse)
rmse
# Out:
# 68476.34087773674

# %%
score =accuracy_score(test['Rent'],Lprediction)
score
# Out:
# 0.071

# %%
train_part1 = train[['BHK','Size','Area Type','Furnishing Status','Bathroom']]
train_part1
# Out:
#       BHK  Size  Area Type  Furnishing Status  Bathroom
# 46      2   400          2                  2         1
# 518     2  1320          1                  1         2
# 3930    3  2395          2                  2         3
# 201     1   700          2                  3         1
# 3520    3  1444          1                  2         3
# ...   ...   ...        ...                ...       ...
# 2224    1   450          2                  2         1
# 2293    1   250          1                  3         1
# 1814    2   575          2                  2         2
# 1950    2   650          1                  2         2
# 4037    2  1090          1                  3         2
#
# [2997 rows x 5 columns]

# %%
modelL = LogisticRegression(max_iter=30,solver='liblinear')
modelL.fit(train_part1,train['Rent'])
modelL
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# LogisticRegression(max_iter=30, solver='liblinear')

# %%
Lprediction=modelL.predict(test[['BHK','Size','Area Type','Furnishing Status','Bathroom']])
df2 = pd.DataFrame(data=Lprediction,columns=["Predicted Rent"])
df2
# Out:
#      Predicted Rent
# 0             15000
# 1             15000
# 2             10000
# 3             15000
# 4             15000
# ..              ...
# 995           15000
# 996           10000
# 997           15000
# 998           30000
# 999            9000
#
# [1000 rows x 1 columns]

# %%
mae = mean_absolute_error(test['Rent'],Lprediction)
mse = mean_squared_error(test['Rent'],Lprediction)
rmse = np.sqrt(mse)
rmse
# Out:
# 60995.11004993761

# %%
score =accuracy_score(test['Rent'],Lprediction)
score
# Out:
# 0.076
